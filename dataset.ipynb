# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.columns
# Out:
# Index(['Passengerid', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Passengerid  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df.shape
# Out:
# (418, 12)

# %%
df.tail(10)
# Out:
#      Passengerid  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
df.sample(4)
# Out:
#      Passengerid  Survived  Pclass  \
# 167         1059         0       3
# 375         1267         1       1
# 227         1119         1       3
# 168         1060         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 167                            Ford, Mr. Edward Watson    male  18.0      2
# 375                           Bowen, Miss. Grace Scott  female  45.0      0
# 227                             McNeill, Miss. Bridget  female   NaN      0
# 168  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  female   NaN      0
#
#      Parch      Ticket      Fare Cabin Embarked
# 167      2  W./C. 6608   34.3750   NaN        S
# 375      0    PC 17608  262.3750   NaN        C
# 227      0      370368    7.7500   NaN        Q
# 168      0       17770   27.7208   NaN        C

# %%
df.columns
# Out:
# Index(['Passengerid', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.rename(columns={"Embarked":"Onboard","Cabin":"First_Cabin","Ticket":"Our_Tickets"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Passengerid  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Our_Tickets  418 non-null    object
#  9   Fare         417 non-null    float64
#  10  First_Cabin  91 non-null     object
#  11  Onboard      418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.head(4)
# Out:
#    Passengerid  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch Our_Tickets    Fare First_Cabin Onboard
# 0  34.5      0      0      330911  7.8292         NaN       Q
# 1  47.0      1      0      363272  7.0000         NaN       S
# 2  62.0      0      0      240276  9.6875         NaN       Q
# 3  27.0      0      0      315154  8.6625         NaN       S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Passengerid  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Our_Tickets  418 non-null    object
#  9   Fare         417 non-null    float64
#  10  First_Cabin  91 non-null     object
#  11  Onboard      418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        Passengerid    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
a = df.describe(include = "all")

# %%
a
# Out:
#         Passengerid    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch Our_Tickets        Fare  \
# count   332.000000  418.000000  418.000000         418  417.000000
# ...

# %%
a.loc[["top","mean"]]
# Out:
#       Passengerid  Survived   Pclass              Name   Sex       Age  \
# top           NaN       NaN      NaN  Kelly, Mr. James  male       NaN
# mean       1100.5  0.363636  2.26555               NaN   NaN  30.27259
#
#          SibSp     Parch Our_Tickets       Fare      First_Cabin Onboard
# top        NaN       NaN    PC 17608        NaN  B57 B59 B63 B66       S
# mean  0.447368  0.392344         NaN  35.627188              NaN     NaN

# %%
a.iloc[[1,3,5]]
# Out:
#         Passengerid  Survived    Pclass Name  Sex        Age    SibSp  \
# unique          NaN       NaN       NaN  418    2        NaN      NaN
# freq            NaN       NaN       NaN    1  266        NaN      NaN
# std      120.810458  0.481622  0.841838  NaN  NaN  14.181209  0.89676
#
#            Parch Our_Tickets       Fare First_Cabin Onboard
# unique       NaN         363        NaN          76       3
# freq         NaN           5        NaN           3     270
# std     0.981429         NaN  55.907576         NaN     NaN

# %%
df.columns
# Out:
# Index(['Passengerid', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Our_Tickets', 'Fare', 'First_Cabin', 'Onboard'],
#       dtype='object')

# %%
df[["Survived"]].value_counts().plot(kind="bar",title="Survived_Persons",color="black")
# Out:
# <Axes: title={'center': 'Survived_Persons'}, xlabel='Survived'>

# %%
df.columns
# Out:
# Index(['Passengerid', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Our_Tickets', 'Fare', 'First_Cabin', 'Onboard'],
#       dtype='object')

# %%
df[["Age"]].value_counts().plot(kind="hist",title="Age",color="red")
# Out:
# <Axes: title={'center': 'Age'}, ylabel='Frequency'>

# %%
df[["Passengerid","Survived"]]
# Out:
#      Passengerid  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# 30           922         0
# 31           923         0
# 32           924         1
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_column',None)
df[["Passengerid","Survived"]]
# Out:
#      Passengerid  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# 30           922         0
# 31           923         0
# 32           924         1
# ...

# %%
df["Fare"].mean()
# Out:
# 35.627188489208635

# %%
df["Fare"].mode
# Out:
# <bound method Series.mode of 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
# 5        9.2250
# 6        7.6292
# 7       29.0000
# 8        7.2292
# 9       24.1500
# 10       7.8958
# 11      26.0000
# 12      82.2667
# 13      26.0000
# 14      61.1750
# 15      27.7208
# 16      12.3500
# 17       7.2250
# 18       7.9250
# 19       7.2250
# 20      59.4000
# 21       3.1708
# 22      31.6833
# 23      61.3792
# 24     262.3750
# 25      14.5000
# 26      61.9792
# 27       7.2250
# 28      30.5000
# 29      21.6792
# 30      26.0000
# 31      31.5000
# 32      20.5750
# 33      23.4500
# 34      57.7500
# 35       7.2292
# 36       8.0500
# 37       8.6625
# 38       9.5000
# 39      56.4958
# 40      13.4167
# 41      26.5500
# 42       7.8500
# 43      13.0000
# 44      52.5542
# 45       7.9250
# 46      29.7000
# 47       7.7500
# 48      76.2917
# 49      15.9000
# 50      60.0000
# 51      15.0333
# 52      23.0000
# ...

# %%
df["Fare"].median()
# Out:
# 14.4542

# %%
df["Name"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                       Kelly, Mr. James
# 1                       Wilkes, Mrs. James (Ellen Needs)
# 2                              Myles, Mr. Thomas Francis
# 3                                       Wirz, Mr. Albert
# 4           Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                             Svensson, Mr. Johan Cervin
# 6                                   Connolly, Miss. Kate
# 7                           Caldwell, Mr. Albert Francis
# 8              Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9                                Davies, Mr. John Samuel
# 10                                      Ilieff, Mr. Ylio
# 11                            Jones, Mr. Charles Cresson
# 12         Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13                                  Howard, Mr. Benjamin
# 14     Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15         del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# ...

# %%
df.isnull().sum()
# Out:
# Passengerid      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df[df["Fare"].isnull()]
# Out:
#      Passengerid  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
df.columns
# Out:
# Index(['Passengerid', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Our_Tickets', 'Fare', 'First_Cabin', 'Onboard'],
#       dtype='object')

# %%
df.groupby("Survived").describe()
# Out:
#          Passengerid                                                           \
#                count         mean         std    min     25%     50%      75%
# Survived
# 0              266.0  1102.620301  119.520499  892.0  999.25  1103.5  1203.75
# 1              152.0  1096.789474  123.345508  893.0  989.50  1093.5  1205.25
#
#                  Pclass                                                 Age  \
#              max  count      mean       std  min  25%  50%  75%  max  count
# Survived
# 0         1309.0  266.0  2.334586  0.808497  1.0  2.0  3.0  3.0  3.0  205.0
# 1         1306.0  152.0  2.144737  0.887051  1.0  1.0  2.0  3.0  3.0  127.0
#
#                                                               SibSp            \
#                mean        std   min   25%   50%   75%   max  count      mean
# Survived
# 0         30.272732  13.389528  0.33  22.0  27.0  40.0  67.0  266.0  0.379699
# 1         30.272362  15.428613  0.17  20.5  27.0  38.5  76.0  152.0  0.565789
#
# ...

# %% [markdown]
# ##### New File :

# %%
df.to_csv("titanic_Data02.csv")
